# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine

# df.to_csv('yellow_tripdata_2024-01.csv')

# %%
df_iter = pd.read_csv('yellow_tripdata_2024-01.csv', iterator=True, chunksize = 100000, index_col=0)
df_iter

# %%
df_parquet = pd.read_parquet('yellow_tripdata_2024-01.parquet')
df_parquet.count()
# Out:
# VendorID                 2964624
# tpep_pickup_datetime     2964624
# tpep_dropoff_datetime    2964624
# passenger_count          2824462
# trip_distance            2964624
# RatecodeID               2824462
# store_and_fwd_flag       2824462
# PULocationID             2964624
# DOLocationID             2964624
# payment_type             2964624
# fare_amount              2964624
# extra                    2964624
# mta_tax                  2964624
# tip_amount               2964624
# tolls_amount             2964624
# improvement_surcharge    2964624
# total_amount             2964624
# congestion_surcharge     2824462
# Airport_fee              2824462
# dtype: int64

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1             1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2             1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3             1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4             1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2024-01-02 13:34:18   2024-01-02 13:38:13              1.0
# 99996         1  2024-01-02 13:47:42   2024-01-02 13:59:26              1.0
# 99997         2  2024-01-02 13:23:51   2024-01-02 13:36:29              1.0
# 99998         2  2024-01-02 13:42:04   2024-01-02 13:48:39              1.0
# 99999         2  2024-01-02 13:54:12   2024-01-02 13:57:25              1.0
#
# ...

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name = 'yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )

# %%
df.head(0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1             1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2             1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3             1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4             1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2024-01-02 13:34:18   2024-01-02 13:38:13              1.0
# 99996         1  2024-01-02 13:47:42   2024-01-02 13:59:26              1.0
# 99997         2  2024-01-02 13:23:51   2024-01-02 13:36:29              1.0
# 99998         2  2024-01-02 13:42:04   2024-01-02 13:48:39              1.0
# 99999         2  2024-01-02 13:54:12   2024-01-02 13:57:25              1.0
#
# ...

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df, name = 'yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1             1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2             1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3             1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4             1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2024-01-02 13:34:18   2024-01-02 13:38:13              1.0
# 99996         1  2024-01-02 13:47:42   2024-01-02 13:59:26              1.0
# 99997         2  2024-01-02 13:23:51   2024-01-02 13:36:29              1.0
# 99998         2  2024-01-02 13:42:04   2024-01-02 13:48:39              1.0
# 99999         2  2024-01-02 13:54:12   2024-01-02 13:57:25              1.0
#
# ...

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 2.1 s, sys: 61.2 ms, total: 2.16 s
# Wall time: 4.14 s
# 1000

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    
    print('insert data..., took %.3f second' %(t_end-t_start))
# Out:
# insert data..., took 4.291 second
# insert data..., took 4.180 second
# insert data..., took 4.384 second
# insert data..., took 4.178 second
# insert data..., took 4.247 second
# insert data..., took 4.603 second
# insert data..., took 4.442 second
# insert data..., took 4.520 second
# insert data..., took 4.479 second
# insert data..., took 4.511 second
# insert data..., took 4.494 second
# insert data..., took 4.448 second
# insert data..., took 4.570 second
# insert data..., took 4.525 second
# insert data..., took 5.063 second
# insert data..., took 4.552 second
# insert data..., took 4.439 second
# insert data..., took 4.431 second
# insert data..., took 4.448 second
# insert data..., took 4.476 second
# insert data..., took 4.460 second
# insert data..., took 4.441 second
# insert data..., took 4.475 second
# insert data..., took 4.434 second
# insert data..., took 4.431 second
# insert data..., took 4.528 second
# insert data..., took 4.475 second
# ...

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Out:
# --2024-11-10 11:17:38--  https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 3.164.82.40, 3.164.82.197, 3.164.82.112, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|3.164.82.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12331 (12K) [text/csv]
# Saving to: ‘taxi_zone_lookup.csv’
#
# taxi_zone_lookup.cs 100%[===================>]  12.04K  --.-KB/s    in 0.01s
#
# 2024-11-10 11:17:39 (840 KB/s) - ‘taxi_zone_lookup.csv’ saved [12331/12331]

# %%
dfzones = pd.read_csv('taxi_zone_lookup.csv')

# %%
dfzones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
dfzones.to_sql(name='zones', con = engine, if_exists='replace')
# Out:
# 265

# %%
import argparse, os, sys

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-09.parquet"
url.rsplit('/', 1)[-1].strip()
# Out:
# 'yellow_tripdata_2024-09.parquet'

# %%
file_name = url.rsplit('/', 1)[-1].strip()
print(f'Downloading {file_name} ...')
# Download file from url
os.system(f"wget {url} -O {file_name}")
# os.system(f'curl {url.strip()} -o {file_name}')
print('\n')
# Out:
# ...
# --2024-12-11 00:57:50--  https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-09.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 3.164.82.40, 3.164.82.160, 3.164.82.197, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|3.164.82.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61170186 (58M) [binary/octet-stream]
# Saving to: ‘yellow_tripdata_2024-09.parquet’
#
#      0K .......... .......... .......... .......... ..........  0%  229K 4m21s
#     50K .......... .......... .......... .......... ..........  0%  720K 2m52s
#    100K .......... .......... .......... .......... ..........  0%  349K 2m51s
#    150K .......... .......... .......... .......... ..........  0%  789K 2m27s
#    200K .......... .......... .......... .......... ..........  0% 1010K 2m9s
#    250K .......... .......... .......... .......... ..........  0%  831K 2m0s
# ...
